# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Reading whale returns
whale_returns_csv = Path("./Resources/whale_returns.csv")
whale_pd = pd.read_csv(whale_returns_csv,index_col="Date", parse_dates=True)
whale_pd.head()
whale_returns_path = Path('Resources/whale_returns.csv')
algo_returns_path = Path('Resources/algo_returns.csv')
sp_tsx_history_path = Path('Resources/sp_tsx_history.csv')

# %%
# Count nulls
# Count nulls
whale_pd.isnull().sum()
# YOUR CODE HERE
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_pd.dropna(inplace=True)
whale_pd.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Reading whale returns
whale_df = pd.read_csv(whale_returns_path,index_col='Date', infer_datetime_format=True, parse_dates=True)
whale_df.head()
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_df = pd.read_csv(algo_returns_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
algo_df.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
# Count nulls
algo_pd.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_pd.dropna(inplace=True)
algo_pd.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sptsx_close_df = pd.read_csv(sp_tsx_history_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
sptsx_close_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sptsx_close_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sptsx_close_df['Close'] = sptsx_close_df['Close'].str.replace(',', '', regex=True)
sptsx_close_df['Close'] = sptsx_close_df['Close'].str.replace('$', '', regex=True)
sptsx_close_df['Close'] = sptsx_close_df['Close'].astype(float)
sptsx_close_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sptsx_df = sptsx_close_df.pct_change()
sptsx_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Rename `Close` Column to be specific to this portfolio.
sptsx_df = sptsx_df.rename(columns={'Close': 'S&P 500 TSX 60'})
sptsx_df.head()
# Out:
#             S&P 500 TSX 60
# Date
# 2012-10-01             NaN
# 2012-10-02        0.001701
# 2012-10-03       -0.002563
# 2012-10-04        0.007137
# 2012-10-05       -0.002305

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_daily_returns = pd.concat([whale_df, algo_df, sptsx_df], axis='columns', join='inner')
combined_daily_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2  S&P 500 TSX 60
# Date
# 2015-03-02  0.003200        0.001950
# 2015-03-03 -0.000949       -0.008530
# 2015-03-04  0.002416       -0.003371
# 2015-03-05  0.004323        0.001344
# 2015-03-06 -0.011460       -0.009972

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_daily_returns.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_cumulative = (1 + combined_daily_returns).cumprod()

# Plot cumulative returns
combined_cumulative.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
whale_df.boxplot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
algo_df.boxplot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
whale_std = whale_df.std()
algo_std = algo_df.std()

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sptsx_std = sptsx_df.std()

# Determine which portfolios are riskier than the S&P TSX 60
combined_std = pd.concat([whale_std, algo_std, sptsx_std])
combined_std = combined_std.sort_values()
combined_std
# Out:
# S&P 500 TSX 60                 0.006637
# PAULSON & CO.INC.              0.006977
# SOROS FUND MANAGEMENT LLC      0.007842
# Algo 1                         0.007972
# Algo 2                         0.008466
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annual_std = combined_daily_returns.std() * np.sqrt(252)
annual_std = annual_std.sort_values()
annual_std
# Out:
# PAULSON & CO.INC.              0.110841
# S&P 500 TSX 60                 0.111613
# Algo 1                         0.120491
# SOROS FUND MANAGEMENT LLC      0.124259
# Algo 2                         0.132121
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# dtype: float64

# %%
# Calculate the annualized standard deviation (252 trading days)
sptsx_std =  sptsx_std.iloc[0]
combined_std > sptsx_std
# Out:
# S&P 500 TSX 60                 False
# PAULSON & CO.INC.               True
# SOROS FUND MANAGEMENT LLC       True
# Algo 1                          True
# Algo 2                          True
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# dtype: bool

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_combined_std = combined_daily_returns.rolling(window=21).std()

# %%
# Plot the rolling standard deviation
combined_daily_returns.rolling(window=21).std().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
returns_correlation = combined_daily_returns.corr()
# Display the correlation matrix
returns_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# S&P 500 TSX 60                                0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# Algo 2                                          0.506689
# S&P 500 TSX 60                                  0.440583
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.750181  0.313795  0.826667
# PAULSON & CO.INC.                          0.540033  0.266363  0.674015
# TIGER GLOBAL MANAGEMENT LLC                0.423524  0.161236  0.506689
# BERKSHIRE HATHAWAY INC                     1.000000  0.289378  0.684609
# Algo 1                                     0.289378  1.000000  0.284840
# Algo 2                                     0.684609  0.284840  1.000000
# S&P 500 TSX 60                             0.557250  0.309759  0.737391
#
#                              S&P 500 TSX 60
# SOROS FUND MANAGEMENT LLC          0.673930
# PAULSON & CO.INC.                  0.486511
# TIGER GLOBAL MANAGEMENT LLC        0.440583
# BERKSHIRE HATHAWAY INC             0.557250
# Algo 1                             0.309759
# Algo 2                             0.737391
# S&P 500 TSX 60                     1.000000

# %%
import seaborn as sns
sns.heatmap(returns_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
berkshire_hathaway_cov = combined_daily_returns['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_daily_returns['S&P 500 TSX 60'])

# Calculate variance of S&P TSX
sptsx_var = combined_daily_returns['S&P 500 TSX 60'].rolling(window=60).var()

# Computing beta
berkshire_hathaway_beta = berkshire_hathaway_cov / sptsx_var

# %%
# Plot beta trend
ax = berkshire_hathaway_beta.plot(figsize=(15,10), title="Rolling 60-Day Beta of Berkshire Hathaway Returns")
berkshire_hathaway_beta.plot(ax=ax)
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Berkshire Hathaway Returns'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_daily_returns.ewm(halflife=21).std().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_daily_returns.mean()  * 252) / annual_std
sharpe_ratios
# Out:
# Algo 1                         1.473237
# Algo 2                         0.402526
# BERKSHIRE HATHAWAY INC         0.467045
# PAULSON & CO.INC.             -0.547594
# S&P 500 TSX 60                 0.199724
# SOROS FUND MANAGEMENT LLC      0.286709
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(figsize=(15,10), kind='bar')
# Out:
# <AxesSubplot:>

# %%
sharpe_ratios.sort_values()
# Out:
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# S&P 500 TSX 60                 0.199724
# SOROS FUND MANAGEMENT LLC      0.286709
# Algo 2                         0.402526
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.473237
# dtype: float64

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
shop_path = Path('Resources/shop_historical.csv')
shop_df = pd.read_csv(shop_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
shop_df = shop_df.rename(columns={'Close': 'SHOP'})
shop_df.head()
# Out:
#            Symbol    SHOP
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
tickers = ['aapl','cost','goog']

# %%
# Reading data from 2nd stock
tsla_path = Path('Resources/l_historical.csv')
tsla_df = pd.read_csv(tsla_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
tsla_df = tsla_df.rename(columns={'Close': 'TSLA'})
tsla_df.head()
# Out:
#            Symbol   TSLA
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
# Reading data from 3rd stock
aapl_path = Path('Resources/otex_historical.csv')
aapl_df = pd.read_csv(aapl_path, index_col='Date', infer_datetime_format=True, parse_dates=True)
aapl_df = aapl_df.rename(columns={'Close': 'AAPL'})
aapl_df.head()
# Out:
#            Symbol   AAPL
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
# Combine all stocks in a single DataFrame
custom_combined = pd.concat([shop_df, tsla_df, aapl_df], axis='columns', join='inner')
custom_combined.head()
# Out:
#            Symbol    SHOP Symbol   TSLA Symbol   AAPL
# Date
# 2018-01-02   SHOP  132.06      L  57.99   OTEX  43.58
# 2018-01-03   SHOP  135.15      L  57.41   OTEX  43.07
# 2018-01-04   SHOP  137.46      L  57.42   OTEX  42.91
# 2018-01-05   SHOP  137.26      L  57.42   OTEX  42.57
# 2018-01-08   SHOP  139.51      L  56.86   OTEX  42.16

# %%
# Reset Date index
custom_combined.set_index(pd.DatetimeIndex(custom_combined.index).date, inplace=True)
custom_combined.head()
# Out:
#            Symbol    SHOP Symbol   TSLA Symbol   AAPL
# 2018-01-02   SHOP  132.06      L  57.99   OTEX  43.58
# 2018-01-03   SHOP  135.15      L  57.41   OTEX  43.07
# 2018-01-04   SHOP  137.46      L  57.42   OTEX  42.91
# 2018-01-05   SHOP  137.26      L  57.42   OTEX  42.57
# 2018-01-08   SHOP  139.51      L  56.86   OTEX  42.16

# %%
# Reorganize portfolio data by having a column per symbol
custom_combined
# Out:
#            Symbol    SHOP Symbol   TSLA Symbol   AAPL
# 2018-01-02   SHOP  132.06      L  57.99   OTEX  43.58
# 2018-01-03   SHOP  135.15      L  57.41   OTEX  43.07
# 2018-01-04   SHOP  137.46      L  57.42   OTEX  42.91
# 2018-01-05   SHOP  137.26      L  57.42   OTEX  42.57
# 2018-01-08   SHOP  139.51      L  56.86   OTEX  42.16
# ...           ...     ...    ...    ...    ...    ...
# 2019-12-20   SHOP  513.22      L  67.90   OTEX  58.68
# 2019-12-23   SHOP  511.62      L  67.68   OTEX  57.89
# 2019-12-24   SHOP  525.39      L  67.67   OTEX  57.44
# 2019-12-27   SHOP  534.76      L  67.78   OTEX  57.70
# 2019-12-30   SHOP  517.79      L  67.33   OTEX  57.19
#
# [501 rows x 6 columns]

# %%
# Calculate daily returns
daily_returns = custom_combined.pct_change()
# Drop NAs
daily_returns.dropna(inplace=True)
# Display sample data
daily_returns.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 # Calculate daily returns
# ----> 2 daily_returns = custom_combined.pct_change()
#       3 # Drop NAs
#       4 daily_returns.dropna(inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10376, in NDFrame.pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10374 shifted = data.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   10375 # Unsupported left operand type for / ("NDFrameT")
# > 10376 rs = data / shifted - 1  # type: ignore[operator]
#   10377 if freq is not None:
#   10378     # Shift method is implemented differently when freq is not None
#   10379     # We want to restore the original index
#   10380     rs = rs.loc[~rs.index.duplicated()]
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:124, in OpsMixin.__truediv__(self, other)
#     122 @unpack_zerodim_and_defer("__truediv__")
#     123 def __truediv__(self, other):
# --> 124     return self._arith_method(other, operator.truediv)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6940, in DataFrame._arith_method(self, other, op)
#    6936 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6938 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> 6940 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6941 return self._construct_result(new_data)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6979, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    6973     # TODO: The previous assertion `assert right._indexed_same(self)`
#    6974     #  fails in cases with empty columns reached via
#    6975     #  _frame_arith_method_with_reindex
#    6976
#    6977     # TODO operate_blockwise expects a manager of the same type
#    6978     with np.errstate(all="ignore"):
# -> 6979         bm = self._mgr.operate_blockwise(
#    6980             # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    6981             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    6982             # "ArrayManager"
#    6983             # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    6984             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    6985             # "BlockManager"
#    6986             right._mgr,  # type: ignore[arg-type]
#    6987             array_op,
#    6988         )
#    6989     return self._constructor(bm)
#    6991 elif isinstance(right, Series) and axis == 1:
#    6992     # axis=1 means we want to operate row-by-row
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1409, in BlockManager.operate_blockwise(self, other, array_op)
#    1405 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1406     """
#    1407     Apply array_op blockwise with another (aligned) BlockManager.
#    1408     """
# -> 1409     return operate_blockwise(self, other, array_op)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\ops.py:63, in operate_blockwise(left, right, array_op)
#      61 res_blks: list[Block] = []
#      62 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 63     res_values = array_op(lvals, rvals)
#      64     if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      65         res_values = res_values.reshape(1, -1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:222, in arithmetic_op(left, right, op)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#     220     _bool_arith_check(op, left, right)
# --> 222     res_values = _na_arithmetic_op(left, right, op)
#     224 return res_values
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:170, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 except TypeError:
#     165     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     166         # For object dtype, fallback to a masked operation (only operating
#     167         #  on the non-missing values)
#     168         # Don't do this for comparisons, as that will handle complex numbers
#     169         #  incorrectly, see GH#32047
# --> 170         result = _masked_arith_op(left, right, op)
#     171     else:
#     172         raise
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:108, in _masked_arith_op(x, y, op)
#     106     # See GH#5284, GH#5035, GH#19448 for historical reference
#     107     if mask.any():
# --> 108         result[mask] = op(xrav[mask], yrav[mask])
#     110 else:
#     111     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

# Display sample data
weights = [1/3, 1/3, 1/3]
weighted_returns = combined_df.dot(weights)
weighted_returns.columns = ['Custom']
print(weighted_returns.columns)
print(weighted_returns.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 5>()
#       2 weights = [1/3, 1/3, 1/3]
#       4 # Calculate portfolio return
# ----> 5 portfolio_returns = daily_returns.dot(weights)
#       6 # Display sample data
#       7 portfolio_returns.head()
#
# NameError: name 'daily_returns' is not defined

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
custom_combined_returns = pd.concat([combined_daily_returns, portfolio_returns], axis='columns', join='inner')
custom_combined_returns = custom_combined_returns.rename(columns={0: 'Custom Returns'})
custom_combined_returns.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 2>()
#       1 # Join your returns DataFrame to the original returns DataFrame
# ----> 2 custom_combined_returns = pd.concat([combined_daily_returns, portfolio_returns], axis='columns', join='inner')
#       3 custom_combined_returns = custom_combined_returns.rename(columns={0: 'Custom Returns'})
#       4 custom_combined_returns.head()
#
# NameError: name 'portfolio_returns' is not defined

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
custom_combined_returns.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 2>()
#       1 # Only compare dates where return data exists for all the stocks (drop NaNs)
# ----> 2 custom_combined_returns.isnull().sum()
#
# NameError: name 'custom_combined_returns' is not defined

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_std = custom_combined_returns.std() * np.sqrt(252)
all_std = all_std.sort_values()
all_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 2>()
#       1 # Calculate the annualized `std`
# ----> 2 all_std = custom_combined_returns.std() * np.sqrt(252)
#       3 all_std = all_std.sort_values()
#       4 all_std
#
# NameError: name 'custom_combined_returns' is not defined

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_all_std = custom_combined_returns.rolling(window=21).std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 2>()
#       1 # Calculate rolling standard deviation
# ----> 2 rolling_all_std = custom_combined_returns.rolling(window=21).std()
#
# NameError: name 'custom_combined_returns' is not defined

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Plot rolling standard deviation
rolling_all_std.plot(figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 2>()
#       1 # Plot rolling standard deviation
# ----> 2 rolling_all_std.plot(figsize=(15,10))
#
# NameError: name 'rolling_all_std' is not defined

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot the correlation
all_returns_correlation = custom_combined_returns.corr()
all_returns_correlation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 2>()
#       1 # Calculate and plot the correlation
# ----> 2 all_returns_correlation = custom_combined_returns.corr()
#       3 all_returns_correlation
#
# NameError: name 'custom_combined_returns' is not defined

# %%
# Calculate and plot Beta
custom_cov = custom_combined_returns['Custom Returns'].rolling(window=60).cov(custom_combined_returns['S&P 500 TSX 60'])
custom_beta = custom_cov / sptsx_var
ay = berkshire_hathaway_beta.plot(figsize=(15,10), title="Rolling 60-Day Beta of Custom Returns")
custom_beta.plot(ax=ay)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 2>()
#       1 # Calculate and plot Beta
# ----> 2 custom_cov = custom_combined_returns['Custom Returns'].rolling(window=60).cov(custom_combined_returns['S&P 500 TSX 60'])
#       3 custom_beta = custom_cov / sptsx_var
#       4 ay = berkshire_hathaway_beta.plot(figsize=(15,10), title="Rolling 60-Day Beta of Custom Returns")
#
# NameError: name 'custom_combined_returns' is not defined

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
custom_beta.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 custom_beta.describe()
#
# NameError: name 'custom_beta' is not defined

# %%
# Calculate Annualized Sharpe Ratios
custom_sharpe_ratios = (custom_combined_returns.mean() * 252) / all_std
custom_sharpe_ratios.sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [77], in <cell line: 2>()
#       1 # Calculate Annualized Sharpe Ratios
# ----> 2 custom_sharpe_ratios = (custom_combined_returns.mean() * 252) / all_std
#       3 custom_sharpe_ratios.sort_values()
#
# NameError: name 'custom_combined_returns' is not defined

# %%
# Visualize the sharpe ratios as a bar plot
custom_sharpe_ratios.plot(figsize=(15,10), kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [78], in <cell line: 2>()
#       1 # Visualize the sharpe ratios as a bar plot
# ----> 2 custom_sharpe_ratios.plot(figsize=(15,10), kind='bar')
#
# NameError: name 'custom_sharpe_ratios' is not defined

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
# To understand the performance of my portfolio against the others it's important to breakdown and interpret the results of the metrics calculated:

# 21-day Standard Deviation - My portfolio presents a highly volatile STD with highest of the group at 29%.

# Correlation - My portfolio is the least postively correlated with Algo 1 at 17%. It is most positively correlated to Berkshire Hathaway at 62%. While it's correlation with all other portfolios sit within the range of 32-54%.

# 60-Day Beta - My portfolio is more volatile than the S&P TSX 60 given that it has has a 60-day beta mean of 1.24 with a min at 0.35 and a max at 2.21.

# Sharpe Ratio - My portfolio is only one of two portfolios to score above 1. It trails behind Algo 1's score of 1.5.

# Overall, my portfolio performs well compared to the other portfolios. It is a suitable portfolio for someone who has a high risk tolerance due to its level of volatility given it's 21-day standard deviation and 60-day Beta metrics. However, it's Sharpe ratio indicates there is good excess reward to its risk.
